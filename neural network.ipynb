# %%
import numpy as np
from matplotlib import pyplot as plt
import os

# %%
# each point is lenghth, width, type(blue = 0, red = 1)
data = [[3,   1.5, 1],
        [2,   1,   0],
        [4,   1.5, 1],
        [3,   1,   0],
        [3.5, 0.5, 1],
        [2,   0.5, 0],
        [5.5, 1,   1],
        [1,   1,   0]]

mystery_flower = [4.5, 1]

# %%
w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

# %%
def sigmoid(x):
    return 1 / (1+np.exp(-x))

def sigmoid_p(x):
    return sigmoid(x) * (1-sigmoid(x))

# %%
t = np.linspace(-6,6,100)
plt.plot(t,sigmoid(t) , c = 'r')
plt.plot(t,sigmoid_p(t) , c = 'b')

# %%
# scatter data

plt.axis([0, 6, 0, 6])
plt.grid()
for i in range(len(data)):
    point = data[i]
    color = 'r'
    if point[2] == 0 :
        color = 'b'
    plt.scatter(point[0], point[1], c = color)

# %%
# training loop

w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

learning_rate = 0.2
costs = []
for i in range(50000):
    ri = np.random.randint(len(data))
    point = data[ri]
    z = w1 * point[0] + w2 * point[1] + b
    h = sigmoid(z)
    
    target = point[2]
    
    cost = np.square(h - target)
    
    
    dcost_pred = 2 * (h - target)
    dpred_dz = sigmoid_p(z)
    dz_dw1 = point[0]
    dz_dw2 = point[1]
    dz_db = 1
    
    dcost_dz = dcost_pred * dpred_dz
    
    dcost_dw1 = dcost_dz * dz_dw1
    dcost_dw2 = dcost_dz * dz_dw2
    dcost_db = dcost_dz * dz_db
    
    w1 = w1 - learning_rate * dcost_dw1
    w2 = w2 - learning_rate * dcost_dw2
    b = b - learning_rate * dcost_db
    
    if i % 100 == 0:
        cost_sum = 0
        for j in range(len(data)):
            point = data[ri]
            z = point[0]*w1 + point[1] * w2 + b
            pred = sigmoid(z)
            target = point[2]
            cost_sum += np.square(pred - target)
        costs.append(cost_sum / len(data))
        
plt.plot(costs)

# %%
for i in range (len(data)):
    point = data[i]
    print point
    z = point[0] * w1 + point[1] * w2 + b
    pred = sigmoid(z)
    print ("pred: {}".format(pred))
# Out:
# [3, 1.5, 1]
# pred: 0.668869288894
# [2, 1, 0]
# pred: 0.000449165127711
# [4, 1.5, 1]
# pred: 0.999477368029
# [3, 1, 0]
# pred: 0.298461275761
# [3.5, 0.5, 1]
# pred: 0.733835456197
# [2, 0.5, 0]
# pred: 9.46356112519e-05
# [5.5, 1, 1]
# pred: 0.999999914773
# [1, 1, 0]
# pred: 4.7464153656e-07

# %%
z = mystery_flower[0] * w1 + mystery_flower[1] * w2 + b
pred = sigmoid(z)
pred
# Out:
# 0.9999193181551167

# %%
os.system("say hi")
# Out:
# 1
